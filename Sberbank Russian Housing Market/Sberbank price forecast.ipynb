# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'data_dictionary.txt',
#  'macro.csv',
#  'macro.csv.zip',
#  'sample_submission.csv',
#  'sample_submission.csv.zip',
#  'Sberbank Price forcast.ipynb',
#  'test.csv.zip',
#  'train.csv',
#  'train.csv.zip']

# %%
train_data = pd.read_csv(".\\train.csv\\train.csv")

# %%
print train_data.shape
#30471 records and 292 columns

train_data.dtypes.value_counts() 
#Most of the features are numerical
#Data inside them has to be checked
# Out:
# (30471, 292)
# int64      157
# float64    119
# object      16
# dtype: int64

# %%
#How to display the output without it getting truncated
pd.set_option('display.max_rows', 300) # Setting the value greater than the number of columns in the data frame
pd.set_option('display.max_columns', 300)

# %%
a = train_data.isnull().sum()

# %%
#Percent of Na values in columns
a.sort_values(ascending = False)/train_data.shape[0] * 100

#10 columns found with Na values greater than 30 percent
# Out:
# hospital_beds_raion                      47.392603
# build_year                               44.649011
# state                                    44.498047
# cafe_avg_price_500                       43.585704
# cafe_sum_500_max_price_avg               43.585704
# cafe_sum_500_min_price_avg               43.585704
# max_floor                                31.413475
# material                                 31.413475
# num_room                                 31.413475
# kitch_sq                                 31.413475
# preschool_quota                          21.948738
# school_quota                             21.938893
# cafe_sum_1000_min_price_avg              21.410521
# cafe_sum_1000_max_price_avg              21.410521
# cafe_avg_price_1000                      21.410521
# life_sq                                  20.947786
# build_count_frame                        16.379508
# build_count_1971-1995                    16.379508
# ...

# %%
train_data.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq  state product_type           sub_area        area_m  \
# 0       NaN       NaN    NaN   Investment           Bibirevo  6.407578e+06
# 1       NaN       NaN    NaN   Investment  Nagatinskij Zaton  9.589337e+06
# 2       NaN       NaN    NaN   Investment     Tekstil'shhiki  4.808270e+06
# 3       NaN       NaN    NaN   Investment             Mitino  1.258354e+07
# 4       NaN       NaN    NaN   Investment          Basmannoe  8.398461e+06
#
# ...

# %%
#train_data['price_doc'].plot.hist(alpha = 0.5, bins = 10000)
#plt.show()
plt.figure();
train_data['price_doc'].hist(bins = 1000)
plt.show()

# %%
#plt.boxplot(train_data['price_data'])
